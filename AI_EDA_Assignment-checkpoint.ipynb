# %%
import pandas as  pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def load_dataset(file_path): 
    return pd.read_csv(file_path)
df = load_dataset("/Users/Dell/.ipynb_checkpoints/DataSet.csv") 
df.head(6)
# Out:
#     Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0  alfa-romero       gas        std        two  convertible         rwd
# 1  alfa-romero       gas        std        two  convertible         rwd
# 2  alfa-romero       gas        std        two    hatchback         rwd
# 3         audi       gas        std       four        sedan         fwd
# 4         audi       gas        std       four        sedan         4wd
# 5         audi       gas        std        two        sedan         fwd
#
#   Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# 0           front        dohc           four          130        mpfi  3.47
# 1           front        dohc           four          130        mpfi  3.47
# 2           front        ohcv            six          152        mpfi  2.68
# 3           front         ohc           four          109        mpfi  3.19
# 4           front         ohc           five          136        mpfi  3.19
# ...

# %%
sns.countplot(data=df, x='Design')
df['Top-RPM'].value_counts()
# Out:
# Top-RPM
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 5250     7
# 4500     7
# 5800     7
# 4200     5
# 4150     5
# 4750     4
# 4350     4
# 5100     3
# 4250     3
# 5900     3
# 4400     3
# 5197     2
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: count, dtype: int64

# %%
df['Design'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['Design'])
# Out:
# (array([ 6.,  0., 70.,  0.,  0., 96.,  0., 25.,  0.,  8.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['Design'])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df['Horse Power'])
# Out:
# <Axes: >

# %%
sns.scatterplot(x='City Mileage', y='Highway Mileage',hue='Stroke',size='Price in Dollars',data=df )
plt.show()

# %%
sns.lineplot(x='City Mileage',y='Design',data=df)
# Out:
# <Axes: xlabel='City Mileage', ylabel='Design'>

# %%
sns.pairplot(data=df,hue='City Mileage')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(pd.crosstab(df['Design'],df['Brand Name']))
# Out:
# <Axes: xlabel='Brand Name', ylabel='Design'>

# %%
df.describe()
# Out:
#        Engine Size        Bore      Stroke  Compression Ratio  Horse Power  \
# count   205.000000  205.000000  205.000000         205.000000   205.000000
# mean    126.907317    3.326634    3.256488          10.142537   104.292683
# std      41.642693    0.271748    0.313688           3.972040    39.520933
# min      61.000000    2.540000    2.070000           7.000000    48.000000
# 25%      97.000000    3.150000    3.110000           8.600000    70.000000
# 50%     120.000000    3.310000    3.290000           9.000000    95.000000
# 75%     141.000000    3.580000    3.410000           9.400000   116.000000
# max     326.000000    3.940000    4.170000          23.000000   288.000000
#
#            Top-RPM  City Mileage  Highway Mileage  Price in Dollars
# count   205.000000    205.000000       205.000000        205.000000
# mean   5126.068293     25.219512        30.751220      16088.580488
# std     477.031307      6.542142         6.886443      40486.372656
# ...
